# %%
import requests
import json

# %%
r=requests.get('https://newsapi.org/v2/top-headlines?country=in&apiKey=334984124b224e0286d9b3a05dcbd778')
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# b'{"status":"ok","totalResults":38,"articles":[{"source":{"id":null,"name":"Moneycontrol"},"author":"Rakesh Patil","title":"Market LIVE Updates: Indices near day\'s high with Nifty around 17,950 led by auto, IT, pharma - Moneycontrol","description":"Stock Market LIVE Updates: Among sectors, Auto, Pharma, FMCG and Information Technology up 1 percent each.","url":"https://www.moneycontrol.com/news/business/markets/share-market-live-updates-stock-market-today-october-31-latest-news-bse-nse-sensex-nifty-covid-coronavirus-larsen-and-toubro-tata-steel-bharti-airtel-jsw-energy-tata-power-dr-reddys-allsec-tech-9415741.html","urlToImage":"https://images.moneycontrol.com/static-mcnews/2022/08/fandosensexniftyderivative-1-770x433.jpg","publishedAt":"2022-10-31T04:25:10Z","content":"October 31, 2022 / 10:13 AM IST\\r\\nTata Power records 85% YoY growth in Q2 consolidated profit at Rs 935 crore\\r\\nTata Power Company has recorded a healthy 85% year-on-year growth in consolidated profit \xe2\x80\
# ...

# %%
json.loads(r.content)
# Out:
# {'status': 'ok',
#  'totalResults': 38,
#  'articles': [{'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Rakesh Patil',
#    'title': "Market LIVE Updates: Indices near day's high with Nifty around 17,950 led by auto, IT, pharma - Moneycontrol",
#    'description': 'Stock Market LIVE Updates: Among sectors, Auto, Pharma, FMCG and Information Technology up 1 percent each.',
#    'url': 'https://www.moneycontrol.com/news/business/markets/share-market-live-updates-stock-market-today-october-31-latest-news-bse-nse-sensex-nifty-covid-coronavirus-larsen-and-toubro-tata-steel-bharti-airtel-jsw-energy-tata-power-dr-reddys-allsec-tech-9415741.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2022/08/fandosensexniftyderivative-1-770x433.jpg',
#    'publishedAt': '2022-10-31T04:25:10Z',
# ...

# %%
data=json.loads(r.content)
data
# Out:
# {'status': 'ok',
#  'totalResults': 38,
#  'articles': [{'source': {'id': None, 'name': 'Moneycontrol'},
#    'author': 'Rakesh Patil',
#    'title': "Market LIVE Updates: Indices near day's high with Nifty around 17,950 led by auto, IT, pharma - Moneycontrol",
#    'description': 'Stock Market LIVE Updates: Among sectors, Auto, Pharma, FMCG and Information Technology up 1 percent each.',
#    'url': 'https://www.moneycontrol.com/news/business/markets/share-market-live-updates-stock-market-today-october-31-latest-news-bse-nse-sensex-nifty-covid-coronavirus-larsen-and-toubro-tata-steel-bharti-airtel-jsw-energy-tata-power-dr-reddys-allsec-tech-9415741.html',
#    'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2022/08/fandosensexniftyderivative-1-770x433.jpg',
#    'publishedAt': '2022-10-31T04:25:10Z',
# ...

# %%
data['articles'][0]
# Out:
# {'source': {'id': None, 'name': 'Moneycontrol'},
#  'author': 'Rakesh Patil',
#  'title': "Market LIVE Updates: Indices near day's high with Nifty around 17,950 led by auto, IT, pharma - Moneycontrol",
#  'description': 'Stock Market LIVE Updates: Among sectors, Auto, Pharma, FMCG and Information Technology up 1 percent each.',
#  'url': 'https://www.moneycontrol.com/news/business/markets/share-market-live-updates-stock-market-today-october-31-latest-news-bse-nse-sensex-nifty-covid-coronavirus-larsen-and-toubro-tata-steel-bharti-airtel-jsw-energy-tata-power-dr-reddys-allsec-tech-9415741.html',
#  'urlToImage': 'https://images.moneycontrol.com/static-mcnews/2022/08/fandosensexniftyderivative-1-770x433.jpg',
#  'publishedAt': '2022-10-31T04:25:10Z',
#  'content': 'October 31, 2022 / 10:13 AM IST\r\nTata Power records 85% YoY growth in Q2 consolidated profit at Rs 935 crore\r\nTata Power Company has recorded a healthy 85% year-on-year growth in consolidated profit … [+641 chars]'}

# %%
data['articles'][1]
# Out:
# {'source': {'id': None, 'name': 'Fresherslive.com'},
#  'author': 'Thamizhalagi B',
#  'title': 'Mohammed Hijab Height How Tall is Mohammed Hijab? - News - News',
#  'description': 'Mohammed Hijab Height: What is Mohammed Hijab Height is the recent search that we could see among the fans. So here in this article, we have updated Mohammed Hijab Height in Feet, inches, and centimeters.',
#  'url': 'https://latestnews.fresherslive.com/articles/mohammed-hijab-height-how-tall-is-mohammed-hijab-1088487',
#  'urlToImage': 'https://img.fresherslive.com/latestnews/images/articles/origin/2022/10/31/mohammed-hijab-height-how-tall-is-mohammed-hijab-635f425fe963b-1667187295.jpg',
#  'publishedAt': '2022-10-31T04:17:12Z',
#  'content': 'Mohammed Hijab Height\r\nWant to know Mohammed Hijab Height? Then read this article and get the exact info on Mohammed Hijab Height. Mohammed Hijab is a Content Creator, Social Media Influencer, Author… [+2943 chars]'}

# %%
data['articles'][1]['author']
# Out:
# 'Thamizhalagi B'

# %%
data['articles'][1]['url']
